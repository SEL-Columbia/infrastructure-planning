# %%
# Given a set of points, compute mst and then divide by number of points

# %%
from os.path import expanduser, join
dataset_folder = expanduser('~/Projects/infrastructure-planning/datasets')
dataset_folder
# Out:
# '/home/rhh/Projects/infrastructure-planning/datasets'

# %%
household_geotable_path = join(dataset_folder, 'senegal-selected-populations.csv')

# %%
cat $household_geotable_path
# Out:
# Name,Latitude,Longitude,Population
# NDOUNE,15.6925578733,-16.4335391924,301
# TOBY,15.6797592961,-16.377985877,57
# MERINA DAKHAR,15.6326203817,-16.432428479,52
# MBAYE MBAYE MAYORO,15.7458322905,-16.3736299776,59
# GABANE OUOLOF,15.7282309584,-16.4790147363,540
# BOUNDOU WOULA I,15.6636715005,-16.5713073433,301
# GABANE PEULH I,15.7343554814,-16.4680162068,301
# SANTHIOU DIAOBE,15.6513986899,-16.5139118679,93
# MERINA NDIAYE PEULH,15.7020539479,-16.3855668379,22
# DAO II,15.6651820605,-16.549432338,245
# NDIAYENE SANTHIE,15.7594303959,-16.422524721,160
# THIOWORE,15.7308213455,-16.4531526672,2031
# THIAR SECK,15.7084658323,-16.4492465675,301
# NDIAYENE PEULH II,15.7468905734,-16.4286317959,296
# THIAR PEULH I,15.6970619073,-16.4482237219,301
# NGUEREUNG PEULH I,15.6555590735,-16.3861309094,301
# KEUR AMADOU MOUNA,15.743051851,-16.550022082,301
# THIARENE SARR I,15.8328649226,-16.4571373752,105
# THIAR NDIAYE II,15.7060680361,-16.4502170868,301
# ...
